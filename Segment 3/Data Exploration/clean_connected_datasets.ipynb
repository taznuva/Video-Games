# %%
import json
import pandas as pd
import numpy as np

from sqlalchemy import create_engine
import psycopg2

from config import db_password

# %%
file_dir = "/Users/caity/Desktop/Final_Project/Entertainment_project/final_datasets"

# %%
#reading data into dataframe
raw_game_data = pd.read_csv (r'/Users/caity/Desktop/Final_Project/Entertainment_project/final_datasets/avg_high_scores_final.csv')
game_data = pd.DataFrame(data=raw_game_data)
game_data
# Out:
#                               title      platform release_date  score  \
# 0           .hack//G.U. Last Recode  PlayStation4    11/3/2017     76
# 1           .hack//G.U. Last Recode            PC     3-Nov-17     69
# 2                            #IDARB       XboxOne    1/30/2015     77
# 3            007: Quantum of Solace  PlayStation3     4-Nov-08     65
# 4            007: Quantum of Solace            PC     4-Nov-08     70
# ...                             ...           ...          ...    ...
# 7405                   Zoo Tycoon 2            PC    11-Nov-04     72
# 7406      Zoo Tycoon: Dinosaur Digs            PC    19-May-02     67
# 7407       Zoo Tycoon: Marine Mania            PC    21-Oct-02     71
# 7408                Zuma's Revenge!            PC    9/15/2009     78
# 7409  Zwei: The Ilvard Insurrection            PC   10/31/2017     79
#
#       user_score              developer  \
# 0            8.1          CyberConnect2
# 1            8.0          CyberConnect2
# 2            6.9  OtherOceanInteractive
# 3            6.6               Treyarch
# 4            6.1        Treyarch,Beenox
# ...          ...                    ...
# 7405         7.9          BlueFangGames
# 7406         7.2          BlueFangGames
# 7407         7.5          BlueFangGames
# 7408         7.5                 PopCap
# 7409         7.3                 Falcom
#
#                                                   genre  critics  users  \
# 0                             Miscellaneous,Compilation       21     64
# 1                             Miscellaneous,Compilation        7     25
# 2                                        Action,General       31     88
# 3     Action,General,Shooter,Shooter,First-Person,Mo...       42     59
# 4     Action,General,Shooter,Shooter,First-Person,Mo...       18     64
# ...                                                 ...      ...    ...
# 7405  Strategy,Tycoon,Management,Tycoon,Business / T...       34     63
# 7406  Strategy,Tycoon,Management,Tycoon,Business / T...        9      9
# 7407  Strategy,Tycoon,Management,Tycoon,Business / T...        8     12
# 7408   Miscellaneous,Puzzle,Action,Puzzle,Puzzle,Action       17     46
# 7409                            Role-Playing,Action RPG        8      7
#
#                    franchise
# 0                       hack
# 1                       hack
# 2                     #IDARB
# 3     007: Quantum of Solace
# 4     007: Quantum of Solace
# ...                      ...
# 7405              Zoo Tycoon
# 7406              Zoo Tycoon
# 7407              Zoo Tycoon
# 7408                    Zuma
# 7409                    Zwei
#
# [7410 rows x 10 columns]

# %%
#reading data into dataframe
raw_sales_data = pd.read_csv (r'/Users/caity/Desktop/Final_Project/Entertainment_project/final_datasets/vgsales_clean_edited.csv')
sales_data = pd.DataFrame(data=raw_sales_data)
sales_data
# Out:
#                                   title      platform  year_of_release  \
# 0                                #IDARB       XboxOne           2009.0
# 1               .hack//G.U. Last Recode  PlayStation4           2012.0
# 2                007: Quantum of Solace            PC           2008.0
# 3                007: Quantum of Solace  PlayStation3           2008.0
# 4                       10 Second Ninja            PC           2009.0
# ...                                 ...           ...              ...
# 2940                       Zoo Tycoon 2            PC           2004.0
# 2941  Zoo Tycoon 2: Ultimate Collection            PC           2008.0
# 2942    Zoo Tycoon: Complete Collection            PC           2003.0
# 2943                      Zumba Fitness  PlayStation3           2010.0
# 2944         Zumba Fitness: World Party       XboxOne           2013.0
#
#           genre               publisher  na_sales  eu_sales  jp_sales  \
# 0     Adventure       DTP Entertainment      0.00      0.09      0.00
# 1        Action      Namco Bandai Games      0.00      0.00      0.47
# 2        Action              Activision      0.01      0.01      0.00
# 3        Action              Activision      0.43      0.51      0.02
# 4        Racing              Rondomedia      0.00      0.02      0.00
# ...         ...                     ...       ...       ...       ...
# 2940   Strategy  Microsoft Game Studios      0.00      0.05      0.00
# 2941   Strategy  Microsoft Game Studios      0.04      0.18      0.00
# 2942   Strategy  Microsoft Game Studios      0.03      0.02      0.00
# 2943     Sports               505 Games      0.28      0.21      0.00
# 2944       Misc   Majesco Entertainment      0.17      0.05      0.00
#
#       other_sales  global_sales  critic_score  critic_count  user_score  \
# 0            0.00          0.09          63.0           6.0         5.8
# 1            0.00          0.47           NaN           NaN         NaN
# 2            0.00          0.03          70.0          18.0         6.3
# 3            0.19          1.14          65.0          42.0         6.6
# 4            0.00          0.02           NaN           NaN         8.0
# ...           ...           ...           ...           ...         ...
# 2940         0.01          0.06          72.0          34.0         8.1
# 2941         0.04          0.26           NaN           NaN         8.4
# 2942         0.01          0.06           NaN           NaN         8.0
# 2943         0.08          0.57           NaN           NaN         3.8
# 2944         0.02          0.24          73.0           5.0         6.2
#
#       user_count                 developer rating
# 0            8.0         DTP Entertainment    NaN
# 1            NaN                       NaN    NaN
# 2           55.0                  Treyarch      T
# 3           47.0                  Treyarch      T
# 4           10.0                       NaN    NaN
# ...          ...                       ...    ...
# 2940        43.0           Blue Fang Games      E
# 2941        14.0           Blue Fang Games      E
# 2942         8.0           Blue Fang Games      E
# 2943         4.0  Pipeworks Software, Inc.      E
# 2944        40.0                  Zoe Mode      E
#
# [2945 rows x 16 columns]

# %%
#create index column 
game_data['title_id'] = game_data.index
sales_data['title_id'] = sales_data.index

# %%
#reordering columns
game_data = game_data[['title_id', 'title', 'platform', 'release_date', 'score', 'user_score', 'developer', 'genre', 'critics', 'users', 'franchise']]
sales_data = sales_data[['title_id', 'title', 'platform', 'year_of_release', 'genre', 'publisher', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'global_sales', 'critic_score', 'critic_count', 'user_score', 'user_count', 'developer', 'rating']]

# %%
# local server connection string
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Game_Data"

# %%
# creating database engine
engine = create_engine(db_string)

# %%
# import the game database to a SQL table, specify name of table & engine
game_data.to_sql(name='games', con=engine)

# %%
# import the sales database to a SQL table, specify name of table & engine
sales_data.to_sql(name='sales', con=engine)

# %%
#game_data.to_csv(r'/Users/caity/Desktop/Final_Project/Entertainment_project/final_datasets/games_df.csv', index = False)

# %%
#sales_data.to_csv(r'/Users/caity/Desktop/Final_Project/Entertainment_project/final_datasets/sales_df.csv', index = False)
