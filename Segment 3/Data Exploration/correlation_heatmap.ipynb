# %% [markdown]
# # Data Correlation

# %%
# Import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load and read data file
df = pd.read_csv('../Resources/finalClean_games.csv')
df
# Out:
#                         Game Name               Franchise     Platform  \
# 0                          #IDARB                  #IDARB         Xbox
# 1          007: Quantum of Solace  007: Quantum of Solace  PlayStation
# 2          007: Quantum of Solace  007: Quantum of Solace           PC
# 3                       0RBITALIS               0RBITALIS           PC
# 4                 10 Second Ninja         10 Second Ninja           PC
# ...                           ...                     ...          ...
# 5492                     inFamous                inFamous  PlayStation
# 5493                   inFamous 2                inFamous  PlayStation
# 5494  inFamous: Festival of Blood                inFamous  PlayStation
# 5495         inFamous: Second Son                inFamous  PlayStation
# 5496                      inbento                 inbento       Switch
#
#       Release Year  Years Since  First Release Year        Main Genre  \
# 0             2015            0                2015            Action
# 1             2008            0                2008            Action
# 2             2008            0                2008            Action
# 3             2015            0                2015           General
# 4             2014            0                2014            Action
# ...            ...          ...                 ...               ...
# 5492          2009            0                2009  Action Adventure
# 5493          2011            2                2009  Action Adventure
# 5494          2011            2                2009  Action Adventure
# 5495          2014            5                2009            Sci-Fi
# 5496          2020            0                2020            Puzzle
#
#      Tier by Score  Critics  Critic_Score  Users  User Score  \
# 0           Tier 3       31            77     88         6.9
# 1           Tier 4       42            65     59         6.6
# 2           Tier 3       18            70     64         6.1
# 3           Tier 3        9            73      4         7.3
# 4           Tier 3       13            72     16         7.1
# ...            ...      ...           ...    ...         ...
# 5492        Tier 2       98            85   1394         8.3
# 5493        Tier 2       90            83   1190         8.6
# 5494        Tier 3       32            78    163         8.0
# 5495        Tier 2       90            80   3691         8.0
# 5496        Tier 3        8            75      4         7.5
#
#                   Developer  Global Sales  \
# 0     OtherOceanInteractive          0.09
# 1                  Treyarch          1.14
# 2           Treyarch,Beenox          0.03
# 3               AlanZucconi           NaN
# 4             GameDesignDan          0.02
# ...                     ...           ...
# 5492            SuckerPunch           NaN
# 5493            SuckerPunch           NaN
# 5494            SuckerPunch           NaN
# 5495            SuckerPunch           NaN
# 5496              Afterburn           NaN
#
#                                              Other Info
# 0                                        Action,General
# 1     Action,General,Shooter,Shooter,First-Person,Mo...
# 2     Action,General,Shooter,Shooter,First-Person,Mo...
# 3                           Miscellaneous,Puzzle,Action
# 4                                  Action,Platformer,2D
# ...                                                 ...
# 5492   Action Adventure,Modern,Sci-Fi,Sci-Fi,Open-World
# 5493          Action Adventure,Sci-Fi,Sci-Fi,Open-World
# 5494          Action Adventure,Sci-Fi,Sci-Fi,Open-World
# 5495          Sci-Fi,Action Adventure,Sci-Fi,Open-World
# 5496                                     Puzzle,General
#
# [5497 rows x 15 columns]

# %%
df.dtypes
# Out:
# Game Name              object
# Franchise              object
# Platform               object
# Release Year            int64
# Years Since             int64
# First Release Year      int64
# Main Genre             object
# Tier by Score          object
# Critics                 int64
# Critic_Score            int64
# Users                   int64
# User Score            float64
# Developer              object
# Global Sales          float64
# Other Info             object
# dtype: object

# %%
df.dropna()
# Out:
#                     Game Name               Franchise     Platform  \
# 0                      #IDARB                  #IDARB         Xbox
# 1      007: Quantum of Solace  007: Quantum of Solace  PlayStation
# 2      007: Quantum of Solace  007: Quantum of Solace           PC
# 4             10 Second Ninja         10 Second Ninja           PC
# 5           10 Second Ninja X         10 Second Ninja         Xbox
# ...                       ...                     ...          ...
# 5437      You Don't Know Jack     You Don't Know Jack  PlayStation
# 5477             Zoo Tycoon 2              Zoo Tycoon           PC
# 5486               echochrome              echochrome  PlayStation
# 5487            echochrome ii              echochrome  PlayStation
# 5490  .hack//G.U. Last Recode                    hack  PlayStation
#
#       Release Year  Years Since  First Release Year Main Genre Tier by Score  \
# 0             2015            0                2015     Action        Tier 3
# 1             2008            0                2008     Action        Tier 4
# 2             2008            0                2008     Action        Tier 3
# 4             2014            0                2014     Action        Tier 3
# 5             2016            2                2014     Action        Tier 2
# ...            ...          ...                 ...        ...           ...
# 5437          2011           11                2000    General        Tier 2
# 5477          2004            3                2001   Strategy        Tier 3
# 5486          2008            0                2008    General        Tier 2
# 5487          2010            2                2008    General        Tier 3
# 5490          2017            0                2017    General        Tier 3
#
#       Critics  Critic_Score  Users  User Score                      Developer  \
# 0          31            77     88         6.9          OtherOceanInteractive
# 1          42            65     59         6.6                       Treyarch
# 2          18            70     64         6.1                Treyarch,Beenox
# 4          13            72     16         7.1                  GameDesignDan
# 5          10            82      8         4.5                  GameDesignDan
# ...       ...           ...    ...         ...                            ...
# 5437       11            82     17         8.2  Jellyvision,IronGalaxyStudios
# 5477       34            72     63         7.9                  BlueFangGames
# 5486       32            81     17         7.3         SCE/WWS,SCEJapanStudio
# 5487       28            79     11         6.5                 SCEJapanStudio
# 5490       21            76     64         8.1                  CyberConnect2
#
#       Global Sales                                         Other Info
# 0             0.09                                     Action,General
# 1             1.14  Action,General,Shooter,Shooter,First-Person,Mo...
# 2             0.03  Action,General,Shooter,Shooter,First-Person,Mo...
# 4             0.02                               Action,Platformer,2D
# 5             0.11                               Action,Platformer,2D
# ...            ...                                                ...
# 5437          0.18  Miscellaneous,Trivia / Game Show,Trivia / Game...
# 5477          0.06  Strategy,Tycoon,Management,Tycoon,Business / T...
# 5486          0.03  Miscellaneous,Puzzle,Action,Puzzle,General,Gen...
# 5487          0.13  Miscellaneous,Puzzle,Action,Puzzle,General,Puz...
# 5490          0.47                          Miscellaneous,Compilation
#
# [1287 rows x 15 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
vg_df = pd.get_dummies(df)

# %%
# Generate correlation map for dataset
corr = df.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
cols = ['Platform', 'Main Genre', 'Developer', 'Critic_Score', 'User Score', 'Global Sales']
for col in cols:
    uniques = df[col].value_counts().keys()
    uniques_dict = {}
    ct = 0
    for i in uniques:
        uniques_dict[i] = ct
        ct += 1

    for k, v in uniques_dict.items():
        df.loc[df[col] == k, col] = v

# %%
df1 = pd.get_dummies(df[['Platform','Main Genre','Critic_Score',
                         'User Score','Global Sales']])
df1 = df1.dropna().reset_index(drop=True)
df1 = df1.astype('float64')

# %%
mask = np.zeros_like(df1.corr())
mask[np.triu_indices_from(mask)] = True
cmap = sns.diverging_palette(730, 300, sep=20, as_cmap=True, s=85, l=15, n=20) # note: 680, 350/470
with sns.axes_style("white"):
    fig, ax = plt.subplots(1,1, figsize=(15,10))
    ax = sns.heatmap(df1.corr(), mask=mask,vmax=0.2, square=True, annot=True, fmt=".3f", cmap="Blues")

# %% [markdown]
# ##
