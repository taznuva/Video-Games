# %%
import json
import pandas as pd
import numpy as np

# %%
file_dir = "/Users/caity/Desktop/Final_Project/Entertainment_project"

# %%
raw_game_data = pd.read_csv (r'/Users/caity/Desktop/Final_Project/Entertainment_project/games-data.csv')
game_data = pd.DataFrame(data=raw_game_data)
game_data
# Out:
#                                      name      platform release_date  score  \
# 0                           Full Throttle            PC    30-Apr-95   86.0
# 1                           Duke Nukem 3D            PC    29-Jan-96   89.0
# 2             Sid Meier's Civilization II            PC    29-Feb-96   94.0
# 3                                Bad Mojo            PC    29-Feb-96   74.0
# 4                           Resident Evil   PlayStation    30-Mar-96   91.0
# ...                                   ...           ...          ...    ...
# 17940  Marvel's Spider-Man: Miles Morales  PlayStation4    12-Nov-20   84.0
# 17941                    Astro's Playroom  PlayStation5    12-Nov-20   82.0
# 17942                             Bugsnax  PlayStation5    12-Nov-20   73.0
# 17943                             Bugsnax            PC    12-Nov-20   68.0
# 17944                                 NaN           NaN          NaN    NaN
#
#       user_score              developer  \
# ...

# %%
# Drop 'players' column from database
game_data = game_data.drop('players', 1)
game_data
# Out:
#                                      name      platform release_date  score  \
# 0                           Full Throttle            PC    30-Apr-95   86.0
# 1                           Duke Nukem 3D            PC    29-Jan-96   89.0
# 2             Sid Meier's Civilization II            PC    29-Feb-96   94.0
# 3                                Bad Mojo            PC    29-Feb-96   74.0
# 4                           Resident Evil   PlayStation    30-Mar-96   91.0
# ...                                   ...           ...          ...    ...
# 17940  Marvel's Spider-Man: Miles Morales  PlayStation4    12-Nov-20   84.0
# 17941                    Astro's Playroom  PlayStation5    12-Nov-20   82.0
# 17942                             Bugsnax  PlayStation5    12-Nov-20   73.0
# 17943                             Bugsnax            PC    12-Nov-20   68.0
# 17944                                 NaN           NaN          NaN    NaN
#
#       user_score              developer  \
# ...

# %%
#comment 
game_data = game_data.rename(columns={"name": "title"})
game_data
# Out:
#                                     title      platform release_date  score  \
# 0                           Full Throttle            PC    30-Apr-95   86.0
# 1                           Duke Nukem 3D            PC    29-Jan-96   89.0
# 2             Sid Meier's Civilization II            PC    29-Feb-96   94.0
# 3                                Bad Mojo            PC    29-Feb-96   74.0
# 4                           Resident Evil   PlayStation    30-Mar-96   91.0
# ...                                   ...           ...          ...    ...
# 17940  Marvel's Spider-Man: Miles Morales  PlayStation4    12-Nov-20   84.0
# 17941                    Astro's Playroom  PlayStation5    12-Nov-20   82.0
# 17942                             Bugsnax  PlayStation5    12-Nov-20   73.0
# 17943                             Bugsnax            PC    12-Nov-20   68.0
# 17944                                 NaN           NaN          NaN    NaN
#
#       user_score              developer  \
# ...

# %%
# count of unique games
len(game_data.title.unique())
# Out:
# 11763

# %%
# count of all games / all rows
len(game_data)
# Out:
# 17945

# %%
# check for null values 
game_data.isna().any()
# Out:
# title           True
# platform        True
# release_date    True
# score           True
# user_score      True
# developer       True
# genre           True
# critics         True
# users           True
# dtype: bool

# %%
# count of games by platform
game_data.groupby('platform').count()
# Out:
#                  title  release_date  score  user_score  developer  genre  \
# platform
# 3DS                400           400    400         400        400    400
# DS                 730           730    730         730        730    730
# Dreamcast          125           125    125         125        125    125
# GameBoyAdvance     444           444    444         444        444    444
# GameCube           452           452    452         452        452    452
# Nintendo64          70            70     70          70         70     70
# PC                4592          4592   4592        4592       4592   4592
# PSP                513           513    513         513        513    513
# PlayStation        188           188    188         188        188    188
# PlayStation2      1418          1418   1418        1418       1418   1418
# PlayStation3      1269          1269   1269        1269       1269   1269
# ...

# %%
# Consoles with no upcoming developments or discontinued game production: 
# 3DS, DS, Dreamcast, GameBoyAdvance, GameCube, Nintendo64, PSP, PlayStationVita, Stadia, Wii, WiiU 
# -- count: 3845
# Discontinued contender consoles:
# PlayStation, PS2, xbox, xbox360
# -- count: 4065

# %%
values = ['3DS' , 'DS' , 'Dreamcast' , 'GameBoyAdvance' , 'GameCube' , 'Nintendo64' , 'PSP' , 'PlayStationVita' , 'Stadia' , 'Wii' , 'WiiU', 'PlayStation', 'PlayStation2', 'Xbox', 'Xbox360']

# %%
# Find Active Selling Games/Consoles 
active_sales = game_data[game_data.platform.isin(values) == False]
active_sales
# Out:
#                                     title      platform release_date  score  \
# 0                           Full Throttle            PC    30-Apr-95   86.0
# 1                           Duke Nukem 3D            PC    29-Jan-96   89.0
# 2             Sid Meier's Civilization II            PC    29-Feb-96   94.0
# 3                                Bad Mojo            PC    29-Feb-96   74.0
# 5                                   Quake            PC    22-Jun-96   94.0
# ...                                   ...           ...          ...    ...
# 17940  Marvel's Spider-Man: Miles Morales  PlayStation4    12-Nov-20   84.0
# 17941                    Astro's Playroom  PlayStation5    12-Nov-20   82.0
# 17942                             Bugsnax  PlayStation5    12-Nov-20   73.0
# 17943                             Bugsnax            PC    12-Nov-20   68.0
# 17944                                 NaN           NaN          NaN    NaN
#
#       user_score              developer  \
# ...

# %%
active_sales.groupby('platform').count()
# Out:
#               title  release_date  score  user_score  developer  genre  \
# platform
# PC             4592          4592   4592        4592       4592   4592
# PlayStation3   1269          1269   1269        1269       1269   1269
# PlayStation4   1928          1928   1928        1928       1928   1928
# PlayStation5      3             3      3           3          3      3
# Switch         1122          1122   1122        1122       1122   1122
# XboxOne        1118          1118   1118        1118       1118   1118
# XboxSeriesX       2             2      2           2          2      2
#
#               critics  users
# platform
# PC               4592   4592
# PlayStation3     1269   1269
# PlayStation4     1928   1928
# PlayStation5        3      3
# Switch           1122   1122
# XboxOne          1118   1118
# XboxSeriesX         2      2

# %%
active_sales.groupby('developer').count()
# Out:
#                                       title  platform  release_date  score  \
# developer
# .theprodukkt                              1         1             1      1
# 101%,ONEOONEGAMES                         1         1             1      1
# 10tons                                   13        13            13     13
# 10tonsEntertainment,10tons                8         8             8      8
# 10tonsEntertainment,10tonsLtd,10tons      1         1             1      1
# ...                                     ...       ...           ...    ...
# tinyBuildGAMES,tinyBuild                  2         2             2      2
# tobyfox                                   1         1             1      1
# tobyfox,8-4                               2         2             2      2
# xiigames                                  1         1             1      1
# yeo                                       1         1             1      1
#
# ...

# %%
active_sales.dtypes
# Out:
# title            object
# platform         object
# release_date     object
# score           float64
# user_score       object
# developer        object
# genre            object
# critics         float64
# users           float64
# dtype: object

# %%
#drop rows that contain specific 'value' in 'column_name'

dropvalue = ["tbd"]
active_sales = active_sales[active_sales.user_score.isin(dropvalue) == False]
active_sales
# Out:
#                                             title      platform release_date  \
# 0                                   Full Throttle            PC    30-Apr-95
# 1                                   Duke Nukem 3D            PC    29-Jan-96
# 2                     Sid Meier's Civilization II            PC    29-Feb-96
# 3                                        Bad Mojo            PC    29-Feb-96
# 5                                           Quake            PC    22-Jun-96
# ...                                           ...           ...          ...
# 17925                                      DIRT 5  PlayStation4     3-Nov-20
# 17926  Jurassic World Evolution: Complete Edition        Switch     3-Nov-20
# 17927              Bakugan: Champions of Vestroia        Switch     3-Nov-20
# 17929      Need for Speed: Hot Pursuit Remastered            PC     6-Nov-20
# 17944                                         NaN           NaN          NaN
#
# ...

# %%
#drop rows that contain specific 'no info' in 'developer' column

dropvalue = ["No info"]
active_sales = active_sales[active_sales.developer.isin(dropvalue) == False]
active_sales
# Out:
#                                             title      platform release_date  \
# 0                                   Full Throttle            PC    30-Apr-95
# 1                                   Duke Nukem 3D            PC    29-Jan-96
# 2                     Sid Meier's Civilization II            PC    29-Feb-96
# 3                                        Bad Mojo            PC    29-Feb-96
# 5                                           Quake            PC    22-Jun-96
# ...                                           ...           ...          ...
# 17925                                      DIRT 5  PlayStation4     3-Nov-20
# 17926  Jurassic World Evolution: Complete Edition        Switch     3-Nov-20
# 17927              Bakugan: Champions of Vestroia        Switch     3-Nov-20
# 17929      Need for Speed: Hot Pursuit Remastered            PC     6-Nov-20
# 17944                                         NaN           NaN          NaN
#
# ...

# %%
avg_high_scores = active_sales[active_sales.score > 64]
avg_high_scores
# Out:
#                                             title      platform release_date  \
# 0                                   Full Throttle            PC    30-Apr-95
# 1                                   Duke Nukem 3D            PC    29-Jan-96
# 2                     Sid Meier's Civilization II            PC    29-Feb-96
# 3                                        Bad Mojo            PC    29-Feb-96
# 5                                           Quake            PC    22-Jun-96
# ...                                           ...           ...          ...
# 17922                                Mad Rat Dead        Switch    30-Oct-20
# 17923             The Dark Pictures - Little Hope  PlayStation4    30-Oct-20
# 17925                                      DIRT 5  PlayStation4     3-Nov-20
# 17926  Jurassic World Evolution: Complete Edition        Switch     3-Nov-20
# 17929      Need for Speed: Hot Pursuit Remastered            PC     6-Nov-20
#
# ...

# %%
avg_high_scores['title_id'] = avg_high_scores.index
avg_high_scores
# Out:
# <ipython-input-19-ee855fc2f19b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_high_scores['title_id'] = avg_high_scores.index
#                                             title      platform release_date  \
# 0                                   Full Throttle            PC    30-Apr-95
# 1                                   Duke Nukem 3D            PC    29-Jan-96
# 2                     Sid Meier's Civilization II            PC    29-Feb-96
# 3                                        Bad Mojo            PC    29-Feb-96
# 5                                           Quake            PC    22-Jun-96
# ...                                           ...           ...          ...
# ...

# %%
avg_high_scores = avg_high_scores[['title_id', 'title', 'platform', 'release_date', 'score', 'user_score', 'developer', 'genre', 'critics', 'users']]

# %%
avg_high_scores.groupby('platform').count()
# Out:
#               title_id  title  release_date  score  user_score  developer  \
# platform
# PC                3454   3454          3454   3454        3454       3454
# PlayStation3       884    884           884    884         884        884
# PlayStation4      1413   1413          1413   1413        1413       1413
# Switch             827    827           827    827         827        827
# XboxOne            832    832           832    832         832        832
#
#               genre  critics  users
# platform
# PC             3454     3454   3454
# PlayStation3    884      884    884
# PlayStation4   1413     1413   1413
# Switch          827      827    827
# XboxOne         832      832    832

# %%
active_sales.to_csv(r'/Users/caity/Desktop/Final_Project/Entertainment_project/active_sales.csv', index = False)

# %%
avg_high_scores.to_csv(r'/Users/caity/Desktop/Final_Project/Entertainment_project/avg_high_scores.csv', index = False)
